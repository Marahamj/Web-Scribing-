# %% [markdown]
# **get all images from imgflip.com**

# %%
import requests
import shutil
import time
from bs4 import BeautifulSoup
import json
import os
import csv
filecsv = open('meme.csv', 'w', encoding='utf8')
# Set the URL you want to webscrape from
url = 'https://imgflip.com/?page='
try:
  os.mkdir("images")
except FileExistsError:
  shutil.rmtree("/content/images")
  os.makedirs("images")
file = open('meme.json', 'w', encoding='utf8')
file.write('[\n')
data = {}
csv_columns = ['author', 'title', 'img']
writer = csv.DictWriter(filecsv, fieldnames=csv_columns)
writer.writeheader()

for page in range(1,11):
    print('---', page, '---')
    r = requests.get(url + str(page))
    print(url + str(page))
    soup = BeautifulSoup(r.content, "html.parser")
    ancher = soup.find_all('div', {'class': "base-unit clearfix"})
    i = 0
    for pt in ancher:
        try:
          img = pt.find('img', {'class': 'base-img'})['src']
        except TypeError:
          try:
            img = pt.find('video', {'class': 'base-img ctx-gif'})['data-src']
          except TypeError:
            img="img not availabe"
        try:
          title = pt.find('h2', {'class': 'base-unit-title'}).find('a').get_text()
        except AttributeError:
          title='not availabe'
        try:
          author = pt.find('a', {'class': 'u-username'}).get_text()
        except AttributeError:
          author='not availabe'

        if img !="img not availabe":
          resource = requests.get("http:"+img)
          # print("status_code",resource.status_code)
          if (img.endswith(".jpg")):
            output = open("images/"+title.replace('/',"")+str(page)+author+".jpg","wb")
          else:
            output = open("images/"+title.replace('/',"")+str(page)+author+".gif","wb")
          output.write(resource.content)

          output.close()
        else: print("img not availabe")
        print("image: "+"https:"+img)
        print("title: ",title)
        print("author: ", author)

        writer.writerow({'author': author.strip('\r\n'), "title":title,"img":img})

        data['img'] = img
        data['title'] = title
        data['author'] = author
        json_data = json.dumps(data, ensure_ascii=False)
        file.write(json_data)
        file.write(",\n")
file.write("\n]")
# defining the api-endpoint
filecsv.close()
file.close()

print(len(os.listdir('/content/images')), "images are extracted")
# Out:
# --- 1 ---
# https://imgflip.com/?page=1
# image: https://i.imgflip.com/9wmut2.gif
# title:  This is how I image the world will end.
# author:  Silly_Memeus
# image: https://i.imgflip.com/9wohjo.gif
# title:  hold up
# author:  country_invader2346
# image: https://i.imgflip.com/9wpnl9.gif
# title:  Would you just eat it? I don't want to lie.
# author:  who_am_i
# image: https://i.imgflip.com/9wpn6l.gif
# title:  When you don't do your job
# author:  who_am_i
# image: https://i.imgflip.com/9wm4q0.jpg
# title:  Oh shit
# author:  Spogebob_Memes-Everyoneismod-
# image: https://i.imgflip.com/9wmf1f.jpg
# title:  You're a winner!
# author:  Memedave
# image: https://i.imgflip.com/9wo8xt.gif
# title:  It's bout' to be a warzone in that joint
# author:  Meme_Lord2.0
# image: https://i.imgflip.com/9wly3r.gif
# title:  creative title
# author:  farballs89
# image: https://i.imgflip.com/9wms00.gif
# title:  Ant Invasion
# author:  Mack-The-Knife
# image: https://i.imgflip.com/9wn3uh.jpg
# title:  Clever title
# author:  Ghostbusting_Nat
# image: https://i.imgflip.com/9wkxfh.jpg
# title:  Simba Shadowy Place
# author:  EyeStrainKun
# image: https://i.imgflip.com/9wobhv.gif
# title:  Caught on Camera
# author:  vBackman
# image: https://i.imgflip.com/9wle8b.gif
# title:  me after giving my 5 year old son a gun
# author:  ascratcherguy
# image: https://i.imgflip.com/9woc8q.gif
# title:  Practice Makes Perfect
# author:  vBackman
# --- 2 ---
# https://imgflip.com/?page=2
# image: https://i.imgflip.com/9wpa4x.gif
# title:  original post
# author:  farballs89
# image: https://i.imgflip.com/9wmsib.gif
# title:  Let the battle to get the last slice of Pizza begin!
# author:  Childerang
# image: https://i.imgflip.com/9wrf2s.gif
# title:  Oops!
# author:  vBackman
# image: https://i.imgflip.com/9wljdm.gif
# title:  disintegrating pistol
# author:  kewlew
# image: https://i.imgflip.com/9wrfyi.gif
# title:  Operator had some mad skills!
# author:  vBackman
# image: https://i.imgflip.com/9wm2cj.jpg
# title:  The Scroll Of Truth
# author:  Ligma4678
# image: https://i.imgflip.com/9wlapl.gif
# title:  this is why theres gonna be ww3 soon - ai art
# author:  DragonSpace9
# image: https://i.imgflip.com/9wnjfq.gif
# title:  Clever Title
# author:  Meme_Lord2.0
# image: https://i.imgflip.com/9wmgw6.jpg
# title:  They're The Same Picture
# author:  ChristopherMoughan
# image: https://i.imgflip.com/9wn4mu.jpg
# title:  Asked and Answered
# author:  Giantsquonk
# image: https://i.imgflip.com/9wpzna.jpg
# title:  Having a McDonalds is the most important factor here. Don't you know?
# author:  Silly_Memeus
# image: https://i.imgflip.com/9wmpz8.gif
# title:  It wasn't even that good!
# author:  Notre_Dame_fan102
# image: https://i.imgflip.com/9wiwb2.gif
# title:  fr
# author:  Notre_Dame_fan102
# image: https://i.imgflip.com/9wc4f7.gif
# title:  Don't always go head first into a problem
# author:  who_am_i
# --- 3 ---
# https://imgflip.com/?page=3
# image: https://i.imgflip.com/9wob6x.gif
# title:  Got bored, so needed some attention
# author:  WaheedAbdullah
# image: https://i.imgflip.com/9wq45j.gif
# title:  Speed racer rex
# author:  blahblahblah243
# image: https://i.imgflip.com/9wpe6z.jpg
# title:  Someone explain to me how Flash Villains just "get away"
# author:  LetsGo_Elect_Brandon_JR
# image: https://i.imgflip.com/9wpj3w.gif
# title:  why here and why now :(
# author:  CartoonM0use_File1
# image: https://i.imgflip.com/9wnjz3.jpg
# title:  Change My Mind
# author:  LllavaCcchicken
# image: https://i.imgflip.com/9woy45.gif
# title:  bleh
# author:  p00pyhead1
# image: https://i.imgflip.com/9wozp0.gif
# title:  elon is NOT cooking with the neuralink
# author:  crunchytickleproductions
# image: https://i.imgflip.com/9wmlm0.jpg
# title:  heartbeat rate
# author:  thisdoesnot_mammathemia
# image: https://i.imgflip.com/9jfibr.gif
# title:  social skills
# author:  AquariusFromYouTube
# image: https://i.imgflip.com/9wnqbi.jpg
# title:  Skeletor wants a gun
# author:  Hardraker
# image: https://i.imgflip.com/9wn6s5.jpg
# title:  free epic Sahawiq
# author:  maplemaker101
# image: https://i.imgflip.com/9wlbqp.jpg
# title:  Purple Reigns
# author:  prie10
# image: https://i.imgflip.com/9wlehi.gif
# title:  chat am I cooked
# author:  ascratcherguy
# image: https://i.imgflip.com/9wfvca.gif
# title:  Friends With a Falcon
# author:  Mack-The-Knife
# --- 4 ---
# https://imgflip.com/?page=4
# image: https://i.imgflip.com/9wnkcy.gif
# title:  me and my friend Ryan tho
# author:  Shinobii
# image: https://i.imgflip.com/9wrmfu.gif
# title:  Upvote if you hate upvote begging
# author:  I_Had_A_Pretty_Endeeparrot8_Day
# image: https://i.imgflip.com/9w6u5s.gif
# title:  Bro Upvoted The Whole Imgflip (Remastered)
# author:  Spogebob_Memes-Everyoneismod-
# image: https://i.imgflip.com/9w7d9s.jpg
# title:  What everyone does in the thumbnail of videos
# author:  who_am_i
# image: https://i.imgflip.com/9wpwc0.jpg
# title:  2019-ah meme, am I right?
# author:  Coonor_More-Tin
# image: https://i.imgflip.com/9wkc6o.gif
# title:  Absolute Truth!
# author:  vBackman
# image: https://i.imgflip.com/9wc5tb.gif
# title:  When you get a charlie horse
# author:  who_am_i
# image: https://i.imgflip.com/9itpl7.jpg
# title:  plot twist
# author:  AquariusFromYouTube
# image: https://i.imgflip.com/9vs71w.gif
# title:  goodbye
# author:  Bradley_Uppercrust_III
# image: https://i.imgflip.com/9wbdeh.gif
# title:  PLEASE don't say i was the only one who did this
# author:  crunchytickleproductions
# image: https://i.imgflip.com/9wk73a.gif
# title:  Pride
# author:  MoFuzzero13
# image: https://i.imgflip.com/9woas1.jpg
# title:  Red Rover, Red Rover Let The Future Come Over
# author:  LadyDeerHeart
# image: https://i.imgflip.com/9wncfq.jpg
# title:  Ain't Technology great
# author:  Giantsquonk
# image: https://i.imgflip.com/9wkt3q.jpg
# title:  not availabe
# author:  .Clock_Master.
# --- 5 ---
# https://imgflip.com/?page=5
# image: https://i.imgflip.com/9wpm08.jpg
# title:  I Bet He's Thinking About Other Women
# author:  Funnyman379
# image: https://i.imgflip.com/9wr72u.jpg
# title:  Nooooooo
# author:  Spogebob_Memes-Everyoneismod-
# image: https://i.imgflip.com/9wrbnn.jpg
# title:  Please do not the coke bottle
# author:  someone_ate_my_cheese
# image: https://i.imgflip.com/9wmoqi.gif
# title:  Teamwork
# author:  Mack-The-Knife
# image: https://i.imgflip.com/9wi01a.gif
# title:  It’s always those idiots
# author:  Memeboat_Silly
# image: https://i.imgflip.com/9wqty9.jpg
# title:  Inage Title
# author:  Strobus
# image: https://i.imgflip.com/9wrsvq.jpg
# title:  Wife material
# author:  Brattmann
# image: https://i.imgflip.com/9wq05p.gif
# title:  Nope
# author:  Sinistermark
# image: https://i.imgflip.com/9jllv3.jpg
# title:  crush
# author:  AquariusFromYouTube
# image: https://i.imgflip.com/9wpayh.jpg
# title:  Trade Offer
# author:  The-memer10
# image: https://i.imgflip.com/9w2xnk.gif
# title:  Cutting the perfect slice
# author:  who_am_i
# image: https://i.imgflip.com/9wld9q.jpg
# title:  Imgflip is dead, I bet you this won't get more than 10 upvotes, let alone 20 or even more
# author:  FerranSoldier
# image: https://i.imgflip.com/9wiqss.gif
# title:  Uh, Oh!
# author:  vBackman
# image: https://i.imgflip.com/9w679u.gif
# title:  Artistic Skills
# author:  Mack-The-Knife
# --- 6 ---
# https://imgflip.com/?page=6
# image: https://i.imgflip.com/9wqgwd.jpg
# title:  Dino meme 5.0
# author:  Sunstorm1216
# image: https://i.imgflip.com/9wntsc.gif
# title:  real
# author:  -_-goose.
# image: https://i.imgflip.com/9wi1hk.gif
# title:  Fr
# author:  Denji.
# image: https://i.imgflip.com/9wkay9.gif
# title:  No Fun!
# author:  vBackman
# image: https://i.imgflip.com/9wose0.jpg
# title:  Newspaper width
# author:  g_user_118346717187993324536
# image: https://i.imgflip.com/9wp0hj.jpg
# title:  FREEDOM FOR EVERYONE
# author:  PackedUp1
# image: https://i.imgflip.com/9wqxav.jpg
# title:  Still Waiting
# author:  WestonTreu
# image: https://i.imgflip.com/9wipyr.gif
# title:  Bella wins for originality!
# author:  vBackman
# image: https://i.imgflip.com/9wmq46.jpg
# title:  but why is Lego so expensive???
# author:  Inferno965
# image: https://i.imgflip.com/9whiya.jpg
# title:  The Problem With Science
# author:  Chatty_Catty_Says
# image: https://i.imgflip.com/9whm4q.jpg
# title:  Global Dumbing is a serious problem
# author:  Giantsquonk
# image: https://i.imgflip.com/9wpr87.jpg
# title:  heh
# author:  The_Drunk_Spinel
# image: https://i.imgflip.com/9wbd7v.gif
# title:  Bullying a Predator
# author:  Mack-The-Knife
# image: https://i.imgflip.com/9vup1h.gif
# title:  True
# author:  Denji.
# --- 7 ---
# https://imgflip.com/?page=7
# image: https://i.imgflip.com/9wi835.gif
# title:  real
# author:  InteractionSystem
# image: https://i.imgflip.com/9woz0y.gif
# title:  no game left behind
# author:  crunchytickleproductions
# image: https://i.imgflip.com/9wp3wj.gif
# title:  favorite song
# author:  Bananeee
# image: https://i.imgflip.com/9wreev.gif
# title:  Who could have guessed
# author:  GoldZghost715
# image: https://i.imgflip.com/9wio2g.jpg
# title:  Finally after all these years...
# author:  AmyMassey
# image: https://i.imgflip.com/9wqi65.jpg
# title:  imagine seeing this in the "hot" section
# author:  Glyder
# image: https://i.imgflip.com/9wjz9t.jpg
# title:  glitchy mickey
# author:  thisdoesnot_mammathemia
# image: https://i.imgflip.com/9wjvaw.jpg
# title:  Vegans
# author:  BlueBlitz
# image: https://i.imgflip.com/9w46az.jpg
# title:  Have a nice summer everyone
# author:  NicolasLichtenberg1
# image: https://i.imgflip.com/9vvyob.jpg
# title:  i just DO this to myself
# author:  kakashi_the_chill_guy
# image: https://i.imgflip.com/9w6ami.jpg
# title:  Fun optional
# author:  bbbadboy
# image: https://i.imgflip.com/9wcmd1.jpg
# title:  There's a new game trending. Match the color samples to Trump's face color.
# author:  MemesByBrad
# image: https://i.imgflip.com/9wkisk.gif
# title:  Kind driver saves deer from being abducted by aliens
# author:  TheNuciestNoo
# image: https://i.imgflip.com/9uewt3.gif
# title:  Why is this a thing
# author:  SomebodyWhoExists
# --- 8 ---
# https://imgflip.com/?page=8
# image: https://i.imgflip.com/9vt0ja.jpg
# title:  It's so annoying how in your face spotify is about getting spotify premium
# author:  Bradley_Uppercrust_III
# image: https://i.imgflip.com/9wr4o8.jpg
# title:  And never ask Jim Benton why Dear Dumb Diary ended.
# author:  pablo2939
# image: https://i.imgflip.com/9wrdpw.jpg
# title:  That's That Me Espresso! (Jokes aside, I'm glad Sabrina is one of the few sane Gen Z people left.)
# author:  KillerShadowChicken2005
# image: https://i.imgflip.com/9wm5ui.gif
# title:  Therapist: All your dreams have a meaning POV my dream
# author:  Rageman200
# image: https://i.imgflip.com/9w3q5m.gif
# title:  One of the most annoying things
# author:  LiveLoveLieLetDie
# image: https://i.imgflip.com/9woy4t.jpg
# title:  AGHHHH
# author:  potatopat
# image: https://i.imgflip.com/9wr0ie.jpg
# title:  How the mighty have fallen
# author:  SomebodyWhoExists
# image: https://i.imgflip.com/9wox04.jpg
# title:  Not physically able to get up
# author:  potatopat
# image: https://i.imgflip.com/9wplzd.jpg
# title:  oh no
# author:  AlaunaRoach
# image: https://i.imgflip.com/9wlx9d.jpg
# title:  Real
# author:  Have_You_Seen_Seren
# image: https://i.imgflip.com/9wdrqa.gif
# title:  :)
# author:  The_Meme_Rag
# image: https://i.imgflip.com/9w99as.jpg
# title:  Padme: "Sounds an awful lot like a silly game." Anakin: "Well, if it works..."
# author:  Silly_Memeus
# image: https://i.imgflip.com/9wbt3p.gif
# title:  Not the Sharpest Knife in the Drawer
# author:  vBackman
# image: https://i.imgflip.com/9wb52i.jpg
# title:  my cat is ded (real)
# author:  NikAneesaSumayyahNikMuaz
# --- 9 ---
